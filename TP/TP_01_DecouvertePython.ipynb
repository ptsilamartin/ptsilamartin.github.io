# %% [markdown]
# <center>
#     <span style="font-size:xx-large;font-style: bold;">
#         TP 01 Découverte de Python
#     </span>
# </center>

# %% [markdown]
# !!! warning Consignes préliminaires
# Ceci est votre notebook contenant les questions, les fonctions et les tests de vos fonctions.
# Penser à sauvegarder régulièrement
# Les cellules peuvent être exécutées via le menu **Run**, via l'icône **Play** ou avec un raccourci clavier :
# * `Shift+Entrée` pour exécuter la cellule et passer à la suivante ;
# * `Ctrl+Entrée` pour exécuter la cellule sans passer à la suivante ;
# * `Alt+Entrée` pour exécuter la cellule et créer une nouvelle cellule en dessous.
#
# **Il faut obligatoirement exécuter vos fonctions.**
#
# **Il faut obligatoirement exécuter des tests (ou faire vos propres tests).**
#
# !!!

# %%
# Exécutez cette cellule pour pouvoir faire les tests
import _TP_01_DecouvertePython as test

# %% [markdown]
# # Premières fonctions

# %% [markdown]
# !!! question Question 1
# Implémenter une fonction `somme(a:int,b:int) -> int` renvoyant la somme des entiers `a` et `b`.
# !!!

# %%
# Écrire ici votre fonction

# %% [markdown]
# !!! tip Test
# Tester votre fonction sur quelques exemples.
# Par exemple, somme(1,1) doit renvoyer 2.
# !!!

# %%
# Tests de la fonction somme
test.somme_test(somme,3,2)
test.somme_test(somme,-1,1)
test.somme_test(somme,-1,2)

# %% [markdown]
# !!! question Question 2
# Implémenter une fonction `racine(a:float) -> float` qui calcule $\sqrt a $. On admettra que $a\geq 0$.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction racine
test.racine_test(racine,0)
test.racine_test(racine,1)
test.racine_test(racine,2)

# %% [markdown]
# !!! question Question 3
#  Implémenter une fonction `inv_racine(a:float) -> float` renvoyant $\frac{1}{\sqrt a}$. On admettra que $a>0$.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction inv_racine
test.inv_racine_test(inv_racine,2)
test.inv_racine_test(inv_racine,1)

# %% [markdown]
# !!! question Question 4
# Implémenter une fonction `est_pair(a:int) -> bool` renvoyant `True` si `a` est pair, `False` sinon.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction est_pair
test.est_pair_test(est_pair,2)
test.est_pair_test(est_pair,1)
test.est_pair_test(est_pair,0)

# %% [markdown]
# # Mes premières boucles

# %% [markdown]
# ## Boucle 1

# %% [markdown]
# !!! question Question 5
# Implémenter une fonction `afficher(n:int) -> None` affichant les entiers compris entre 0 et $n$ inclus. On utilisera une boucle `for`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Appeler votre fonction.

# %% [markdown]
# !!! question Question 6
# Implémenter une fonction `puissance_2_for(n:int) -> int` renvoyant $2^n$. On utilisera une boucle `for`. On n'utilisera pas `**`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction puissance_2_for
test.puissance_2_for_test(puissance_2_for,7)
test.puissance_2_for_test(puissance_2_for,3)
test.puissance_2_for_test(puissance_2_for,0)

# %% [markdown]
# !!! question Question 7
# Implémenter une fonction `puissance_2_while(n:int) -> int` renvoyant $2^n$. On utilisera une boucle `while`. On n'utilisera pas `**`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction puissance_2_while
test.puissance_2_while_test(puissance_2_while,7)
test.puissance_2_while_test(puissance_2_while,3)
test.puissance_2_while_test(puissance_2_while,0)

# %% [markdown]
# !!! question Question 8
# Implémenter une fonction `puissance_for(a:float,n:int) -> float` renvoyant $a^n$. On utilisera une boucle `for`. On n'utilisera pas `**`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction puissance_for
test.puissance_for_test(puissance_for,2,4)
test.puissance_for_test(puissance_for,2.5,4)
test.puissance_for_test(puissance_for,12,0)
test.puissance_for_test(puissance_for,0,4)

# %% [markdown]
# !!! question Question 9
# Implémenter une fonction `puissance_while(a:float,n:int) -> float` renvoyant $a^n$. On utilisera une boucle `while`. On n'utilisera pas `**`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction puissance_while
test.puissance_while_test(puissance_while,2,4)
test.puissance_while_test(puissance_while,2.5,4)
test.puissance_while_test(puissance_while,12,0)
test.puissance_while_test(puissance_while,0,4)

# %% [markdown]
# !!! question Question 9
# Implémenter une fonction `puissance(a:float,n:int) -> float` renvoyant $a^n$. On n'utilisera pas de boucle.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction puissance
test.puissance_test(puissance,2,4)
test.puissance_test(puissance,2.5,4)
test.puissance_test(puissance,12,0)
test.puissance_test(puissance,0,4)

# %% [markdown]
# !!! question Question 10
# Implémenter une fonction `factoriel_while(n:int) -> int` renvoyant $n!$. On utilisera une boucle `while`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction factoriel_while
test.factoriel_while_test(factoriel_while,1)
test.factoriel_while_test(factoriel_while,4)
test.factoriel_while_test(factoriel_while,0)

# %% [markdown]
# !!! question Question 11
# Implémenter une fonction `factoriel_for(n:int) -> int` renvoyant $n!$. On utilisera une boucle `for`.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction factoriel_for
test.factoriel_for_test(factoriel_for,1)
test.factoriel_for_test(factoriel_for,4)
test.factoriel_for_test(factoriel_for,0)

# %% [markdown]
# !!! question Question 12
# Implémenter une fonction `binomial(n:int,k:int) -> int` renvoyant $\frac{n!}{k!(n-k)!}$.
# !!!

# %%
# Écrire ici votre fonction

# %%
# Tests de la fonction binommial
test.binomial_test(binomial,3,1)
test.binomial_test(binomial,5,3)
test.binomial_test(binomial,5,0)
